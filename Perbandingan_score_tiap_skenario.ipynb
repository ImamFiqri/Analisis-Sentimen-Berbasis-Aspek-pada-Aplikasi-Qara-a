# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
skenario_1 = {
    'Fitur': {'Precision': 0.54, 'Recall': 0.50, 'F1-Score': 0.52, 'Accuracy': 0.60},
    'Pelayanan': {'Precision': 0.17, 'Recall': 0.05, 'F1-Score': 0.08, 'Accuracy': 0.60},
    'Pengalaman': {'Precision': 0.49, 'Recall': 0.49, 'F1-Score': 0.49, 'Accuracy': 0.55},
    'Religiusitas': {'Precision': 0.55, 'Recall': 0.44, 'F1-Score': 0.49, 'Accuracy': 0.99},
    'Umum': {'Precision': 0.81, 'Recall': 0.64, 'F1-Score': 0.71, 'Accuracy': 0.81}
}

skenario_2 = {
    'Fitur': {'Precision': 0.55, 'Recall': 0.48, 'F1-Score': 0.51, 'Accuracy': 0.61},
    'Pelayanan': {'Precision': 0.00, 'Recall': 0.00, 'F1-Score': 0.00, 'Accuracy': 0.61},
    'Pengalaman': {'Precision': 0.49, 'Recall': 0.52, 'F1-Score': 0.50, 'Accuracy': 0.56},
    'Religiusitas': {'Precision': 0.46, 'Recall': 0.50, 'F1-Score': 0.48, 'Accuracy': 0.99},
    'Umum': {'Precision': 0.82, 'Recall': 0.65, 'F1-Score': 0.70, 'Accuracy': 0.81}
}

skenario_3 = {
    'Fitur': {'Precision': 0.49, 'Recall': 0.48, 'F1-Score': 0.48, 'Accuracy': 0.58},
    'Pelayanan': {'Precision': 0.60, 'Recall': 0.25, 'F1-Score': 0.35, 'Accuracy': 0.61},
    'Pengalaman': {'Precision': 0.45, 'Recall': 0.51, 'F1-Score': 0.48, 'Accuracy': 0.54},
    'Religiusitas': {'Precision': 0.42, 'Recall': 0.45, 'F1-Score': 0.43, 'Accuracy': 0.99},
    'Umum': {'Precision': 0.79, 'Recall': 0.64, 'F1-Score': 0.69, 'Accuracy': 0.81}
}

aspects = list(skenario_1.keys())

# Precision
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.2
bar_spacing = 0.1

ax.bar([x - bar_width - bar_spacing for x in range(len(aspects))], [skenario_1[a]['Precision'] for a in aspects], bar_width, label='Skenario 1', color='goldenrod')
ax.bar([x - bar_spacing for x in range(len(aspects))], [skenario_2[a]['Precision'] for a in aspects], bar_width, label='Skenario 2', color='gray')
ax.bar([x + bar_spacing for x in range(len(aspects))], [skenario_3[a]['Precision'] for a in aspects], bar_width, label='Skenario 3', color='darkgreen')

ax.set_xticks(range(len(aspects)))
ax.set_xticklabels(aspects)
ax.set_title('Perbandingan Precision Antar Skenario')
ax.set_ylabel('Precision')

ax.legend(loc='upper left')
plt.tight_layout()

# Recall
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar([x - bar_width - bar_spacing for x in range(len(aspects))], [skenario_1[a]['Recall'] for a in aspects], bar_width, label='Skenario 1', color='goldenrod')
ax.bar([x - bar_spacing for x in range(len(aspects))], [skenario_2[a]['Recall'] for a in aspects], bar_width, label='Skenario 2', color='gray')
ax.bar([x + bar_spacing for x in range(len(aspects))], [skenario_3[a]['Recall'] for a in aspects], bar_width, label='Skenario 3', color='darkgreen')

ax.set_xticks(range(len(aspects)))
ax.set_xticklabels(aspects)
ax.set_title('Perbandingan Recall Antar Skenario')
ax.set_ylabel('Recall')

ax.legend(loc='upper left')
plt.tight_layout()

# F1-Score
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar([x - bar_width - bar_spacing for x in range(len(aspects))], [skenario_1[a]['F1-Score'] for a in aspects], bar_width, label='Skenario 1', color='goldenrod')
ax.bar([x - bar_spacing for x in range(len(aspects))], [skenario_2[a]['F1-Score'] for a in aspects], bar_width, label='Skenario 2', color='gray')
ax.bar([x + bar_spacing for x in range(len(aspects))], [skenario_3[a]['F1-Score'] for a in aspects], bar_width, label='Skenario 3', color='darkgreen')

ax.set_xticks(range(len(aspects)))
ax.set_xticklabels(aspects)
ax.set_title('Perbandingan F1-Score Antar Skenario')
ax.set_ylabel('F1-Score')

ax.legend(loc='upper left')
plt.tight_layout()

# Accuracy
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar([x - bar_width - bar_spacing for x in range(len(aspects))], [skenario_1[a]['Accuracy'] for a in aspects], bar_width, label='Skenario 1', color='goldenrod')
ax.bar([x - bar_spacing for x in range(len(aspects))], [skenario_2[a]['Accuracy'] for a in aspects], bar_width, label='Skenario 2', color='gray')
ax.bar([x + bar_spacing for x in range(len(aspects))], [skenario_3[a]['Accuracy'] for a in aspects], bar_width, label='Skenario 3', color='darkgreen')

ax.set_xticks(range(len(aspects)))
ax.set_xticklabels(aspects)
ax.set_title('Perbandingan Accuracy Antar Skenario')
ax.set_ylabel('Accuracy')

ax.legend(loc='upper left')
plt.tight_layout()
